# %% [markdown]
# https://docs.llamaindex.ai/en/stable/examples/pipeline/query_pipeline_sql.html

# %%
import pandas as pd
from pathlib import Path

data_dir = Path("./WikiTableQuestions/csv/204-csv")
csv_files = sorted([f for f in data_dir.glob("*.csv")])
dfs = []
for csv_file in csv_files:
    print(f"processing file: {csv_file}")
    try:
        df = pd.read_csv(csv_file)
        dfs.append(df)
    except Exception as e:
        print(f"Error parsing {csv_file}: {str(e)}")
# Out:
# processing file: WikiTableQuestions/csv/204-csv/0.csv
# processing file: WikiTableQuestions/csv/204-csv/1.csv
# processing file: WikiTableQuestions/csv/204-csv/10.csv
# processing file: WikiTableQuestions/csv/204-csv/100.csv
# processing file: WikiTableQuestions/csv/204-csv/101.csv
# processing file: WikiTableQuestions/csv/204-csv/102.csv
# processing file: WikiTableQuestions/csv/204-csv/103.csv
# processing file: WikiTableQuestions/csv/204-csv/104.csv
# processing file: WikiTableQuestions/csv/204-csv/105.csv
# processing file: WikiTableQuestions/csv/204-csv/106.csv
# processing file: WikiTableQuestions/csv/204-csv/107.csv
# processing file: WikiTableQuestions/csv/204-csv/108.csv
# processing file: WikiTableQuestions/csv/204-csv/109.csv
# processing file: WikiTableQuestions/csv/204-csv/11.csv
# processing file: WikiTableQuestions/csv/204-csv/110.csv
# processing file: WikiTableQuestions/csv/204-csv/111.csv
# processing file: WikiTableQuestions/csv/204-csv/112.csv
# processing file: WikiTableQuestions/csv/204-csv/113.csv
# processing file: WikiTableQuestions/csv/204-csv/114.csv
# processing file: WikiTableQuestions/csv/204-csv/115.csv
# processing file: WikiTableQuestions/csv/204-csv/116.csv
# processing file: WikiTableQuestions/csv/204-csv/117.csv
# processing file: WikiTableQuestions/csv/204-csv/118.csv
# processing file: WikiTableQuestions/csv/204-csv/119.csv
# processing file: WikiTableQuestions/csv/204-csv/12.csv
# processing file: WikiTableQuestions/csv/204-csv/120.csv
# processing file: WikiTableQuestions/csv/204-csv/121.csv
# processing file: WikiTableQuestions/csv/204-csv/122.csv
# processing file: WikiTableQuestions/csv/204-csv/123.csv
# processing file: WikiTableQuestions/csv/204-csv/124.csv
# processing file: WikiTableQuestions/csv/204-csv/125.csv
# processing file: WikiTableQuestions/csv/204-csv/126.csv
# processing file: WikiTableQuestions/csv/204-csv/127.csv
# processing file: WikiTableQuestions/csv/204-csv/128.csv
# processing file: WikiTableQuestions/csv/204-csv/129.csv
# processing file: WikiTableQuestions/csv/204-csv/13.csv
# processing file: WikiTableQuestions/csv/204-csv/130.csv
# processing file: WikiTableQuestions/csv/204-csv/131.csv
# processing file: WikiTableQuestions/csv/204-csv/132.csv
# processing file: WikiTableQuestions/csv/204-csv/133.csv
# processing file: WikiTableQuestions/csv/204-csv/134.csv
# processing file: WikiTableQuestions/csv/204-csv/135.csv
# processing file: WikiTableQuestions/csv/204-csv/136.csv
# processing file: WikiTableQuestions/csv/204-csv/137.csv
# processing file: WikiTableQuestions/csv/204-csv/138.csv
# processing file: WikiTableQuestions/csv/204-csv/139.csv
# processing file: WikiTableQuestions/csv/204-csv/14.csv
# processing file: WikiTableQuestions/csv/204-csv/140.csv
# processing file: WikiTableQuestions/csv/204-csv/141.csv
# processing file: WikiTableQuestions/csv/204-csv/142.csv
# processing file: WikiTableQuestions/csv/204-csv/143.csv
# processing file: WikiTableQuestions/csv/204-csv/144.csv
# processing file: WikiTableQuestions/csv/204-csv/145.csv
# processing file: WikiTableQuestions/csv/204-csv/146.csv
# processing file: WikiTableQuestions/csv/204-csv/147.csv
# processing file: WikiTableQuestions/csv/204-csv/148.csv
# processing file: WikiTableQuestions/csv/204-csv/149.csv
# processing file: WikiTableQuestions/csv/204-csv/15.csv
# processing file: WikiTableQuestions/csv/204-csv/150.csv
# processing file: WikiTableQuestions/csv/204-csv/151.csv
# processing file: WikiTableQuestions/csv/204-csv/152.csv
# processing file: WikiTableQuestions/csv/204-csv/153.csv
# processing file: WikiTableQuestions/csv/204-csv/154.csv
# processing file: WikiTableQuestions/csv/204-csv/155.csv
# processing file: WikiTableQuestions/csv/204-csv/156.csv
# processing file: WikiTableQuestions/csv/204-csv/157.csv
# processing file: WikiTableQuestions/csv/204-csv/158.csv
# processing file: WikiTableQuestions/csv/204-csv/159.csv
# processing file: WikiTableQuestions/csv/204-csv/16.csv
# processing file: WikiTableQuestions/csv/204-csv/160.csv
# processing file: WikiTableQuestions/csv/204-csv/161.csv
# processing file: WikiTableQuestions/csv/204-csv/162.csv
# processing file: WikiTableQuestions/csv/204-csv/163.csv
# processing file: WikiTableQuestions/csv/204-csv/164.csv
# processing file: WikiTableQuestions/csv/204-csv/165.csv
# processing file: WikiTableQuestions/csv/204-csv/166.csv
# processing file: WikiTableQuestions/csv/204-csv/167.csv
# processing file: WikiTableQuestions/csv/204-csv/168.csv
# processing file: WikiTableQuestions/csv/204-csv/169.csv
# processing file: WikiTableQuestions/csv/204-csv/17.csv
# processing file: WikiTableQuestions/csv/204-csv/170.csv
# processing file: WikiTableQuestions/csv/204-csv/171.csv
# processing file: WikiTableQuestions/csv/204-csv/172.csv
# processing file: WikiTableQuestions/csv/204-csv/173.csv
# processing file: WikiTableQuestions/csv/204-csv/174.csv
# processing file: WikiTableQuestions/csv/204-csv/175.csv
# processing file: WikiTableQuestions/csv/204-csv/176.csv
# Error parsing WikiTableQuestions/csv/204-csv/176.csv: Error tokenizing data. C error: Expected 5 fields in line 35, saw 6
#
# processing file: WikiTableQuestions/csv/204-csv/177.csv
# processing file: WikiTableQuestions/csv/204-csv/178.csv
# processing file: WikiTableQuestions/csv/204-csv/179.csv
# processing file: WikiTableQuestions/csv/204-csv/18.csv
# processing file: WikiTableQuestions/csv/204-csv/180.csv
# processing file: WikiTableQuestions/csv/204-csv/181.csv
# processing file: WikiTableQuestions/csv/204-csv/182.csv
# processing file: WikiTableQuestions/csv/204-csv/183.csv
# processing file: WikiTableQuestions/csv/204-csv/184.csv
# Error parsing WikiTableQuestions/csv/204-csv/184.csv: Error tokenizing data. C error: Expected 5 fields in line 16, saw 6
#
# processing file: WikiTableQuestions/csv/204-csv/185.csv
# processing file: WikiTableQuestions/csv/204-csv/186.csv
# processing file: WikiTableQuestions/csv/204-csv/187.csv
# processing file: WikiTableQuestions/csv/204-csv/188.csv
# processing file: WikiTableQuestions/csv/204-csv/189.csv
# processing file: WikiTableQuestions/csv/204-csv/19.csv
# processing file: WikiTableQuestions/csv/204-csv/190.csv
# processing file: WikiTableQuestions/csv/204-csv/191.csv
# processing file: WikiTableQuestions/csv/204-csv/192.csv
# processing file: WikiTableQuestions/csv/204-csv/193.csv
# processing file: WikiTableQuestions/csv/204-csv/194.csv
# processing file: WikiTableQuestions/csv/204-csv/195.csv
# processing file: WikiTableQuestions/csv/204-csv/196.csv
# processing file: WikiTableQuestions/csv/204-csv/197.csv
# processing file: WikiTableQuestions/csv/204-csv/198.csv
# processing file: WikiTableQuestions/csv/204-csv/199.csv
# processing file: WikiTableQuestions/csv/204-csv/2.csv
# processing file: WikiTableQuestions/csv/204-csv/20.csv
# processing file: WikiTableQuestions/csv/204-csv/200.csv
# processing file: WikiTableQuestions/csv/204-csv/201.csv
# processing file: WikiTableQuestions/csv/204-csv/202.csv
# processing file: WikiTableQuestions/csv/204-csv/203.csv
# processing file: WikiTableQuestions/csv/204-csv/204.csv
# processing file: WikiTableQuestions/csv/204-csv/205.csv
# processing file: WikiTableQuestions/csv/204-csv/206.csv
# processing file: WikiTableQuestions/csv/204-csv/207.csv
# processing file: WikiTableQuestions/csv/204-csv/208.csv
# processing file: WikiTableQuestions/csv/204-csv/209.csv
# processing file: WikiTableQuestions/csv/204-csv/21.csv
# processing file: WikiTableQuestions/csv/204-csv/210.csv
# processing file: WikiTableQuestions/csv/204-csv/211.csv
# processing file: WikiTableQuestions/csv/204-csv/212.csv
# processing file: WikiTableQuestions/csv/204-csv/213.csv
# processing file: WikiTableQuestions/csv/204-csv/214.csv
# processing file: WikiTableQuestions/csv/204-csv/215.csv
# processing file: WikiTableQuestions/csv/204-csv/216.csv
# processing file: WikiTableQuestions/csv/204-csv/217.csv
# processing file: WikiTableQuestions/csv/204-csv/218.csv
# processing file: WikiTableQuestions/csv/204-csv/219.csv
# processing file: WikiTableQuestions/csv/204-csv/22.csv
# processing file: WikiTableQuestions/csv/204-csv/220.csv
# Error parsing WikiTableQuestions/csv/204-csv/220.csv: Error tokenizing data. C error: Expected 7 fields in line 36, saw 8
#
# processing file: WikiTableQuestions/csv/204-csv/221.csv
# processing file: WikiTableQuestions/csv/204-csv/222.csv
# processing file: WikiTableQuestions/csv/204-csv/223.csv
# processing file: WikiTableQuestions/csv/204-csv/224.csv
# processing file: WikiTableQuestions/csv/204-csv/225.csv
# processing file: WikiTableQuestions/csv/204-csv/226.csv
# processing file: WikiTableQuestions/csv/204-csv/227.csv
# processing file: WikiTableQuestions/csv/204-csv/228.csv
# processing file: WikiTableQuestions/csv/204-csv/229.csv
# processing file: WikiTableQuestions/csv/204-csv/23.csv
# processing file: WikiTableQuestions/csv/204-csv/230.csv
# processing file: WikiTableQuestions/csv/204-csv/231.csv
# processing file: WikiTableQuestions/csv/204-csv/232.csv
# processing file: WikiTableQuestions/csv/204-csv/233.csv
# processing file: WikiTableQuestions/csv/204-csv/234.csv
# processing file: WikiTableQuestions/csv/204-csv/235.csv
# processing file: WikiTableQuestions/csv/204-csv/236.csv
# processing file: WikiTableQuestions/csv/204-csv/237.csv
# processing file: WikiTableQuestions/csv/204-csv/238.csv
# processing file: WikiTableQuestions/csv/204-csv/239.csv
# processing file: WikiTableQuestions/csv/204-csv/24.csv
# processing file: WikiTableQuestions/csv/204-csv/240.csv
# processing file: WikiTableQuestions/csv/204-csv/241.csv
# processing file: WikiTableQuestions/csv/204-csv/242.csv
# processing file: WikiTableQuestions/csv/204-csv/243.csv
# processing file: WikiTableQuestions/csv/204-csv/244.csv
# processing file: WikiTableQuestions/csv/204-csv/245.csv
# processing file: WikiTableQuestions/csv/204-csv/246.csv
# processing file: WikiTableQuestions/csv/204-csv/247.csv
# processing file: WikiTableQuestions/csv/204-csv/248.csv
# processing file: WikiTableQuestions/csv/204-csv/249.csv
# processing file: WikiTableQuestions/csv/204-csv/25.csv
# processing file: WikiTableQuestions/csv/204-csv/250.csv
# processing file: WikiTableQuestions/csv/204-csv/251.csv
# processing file: WikiTableQuestions/csv/204-csv/252.csv
# processing file: WikiTableQuestions/csv/204-csv/253.csv
# processing file: WikiTableQuestions/csv/204-csv/254.csv
# processing file: WikiTableQuestions/csv/204-csv/255.csv
# processing file: WikiTableQuestions/csv/204-csv/256.csv
# processing file: WikiTableQuestions/csv/204-csv/257.csv
# processing file: WikiTableQuestions/csv/204-csv/258.csv
# processing file: WikiTableQuestions/csv/204-csv/259.csv
# processing file: WikiTableQuestions/csv/204-csv/26.csv
# processing file: WikiTableQuestions/csv/204-csv/260.csv
# processing file: WikiTableQuestions/csv/204-csv/261.csv
# processing file: WikiTableQuestions/csv/204-csv/262.csv
# processing file: WikiTableQuestions/csv/204-csv/263.csv
# processing file: WikiTableQuestions/csv/204-csv/264.csv
# processing file: WikiTableQuestions/csv/204-csv/265.csv
# processing file: WikiTableQuestions/csv/204-csv/266.csv
# processing file: WikiTableQuestions/csv/204-csv/267.csv
# processing file: WikiTableQuestions/csv/204-csv/268.csv
# processing file: WikiTableQuestions/csv/204-csv/269.csv
# processing file: WikiTableQuestions/csv/204-csv/27.csv
# processing file: WikiTableQuestions/csv/204-csv/270.csv
# processing file: WikiTableQuestions/csv/204-csv/271.csv
# processing file: WikiTableQuestions/csv/204-csv/272.csv
# processing file: WikiTableQuestions/csv/204-csv/273.csv
# processing file: WikiTableQuestions/csv/204-csv/274.csv
# processing file: WikiTableQuestions/csv/204-csv/275.csv
# processing file: WikiTableQuestions/csv/204-csv/276.csv
# processing file: WikiTableQuestions/csv/204-csv/277.csv
# processing file: WikiTableQuestions/csv/204-csv/278.csv
# processing file: WikiTableQuestions/csv/204-csv/279.csv
# processing file: WikiTableQuestions/csv/204-csv/28.csv
# processing file: WikiTableQuestions/csv/204-csv/280.csv
# processing file: WikiTableQuestions/csv/204-csv/281.csv
# processing file: WikiTableQuestions/csv/204-csv/282.csv
# processing file: WikiTableQuestions/csv/204-csv/283.csv
# processing file: WikiTableQuestions/csv/204-csv/284.csv
# processing file: WikiTableQuestions/csv/204-csv/285.csv
# processing file: WikiTableQuestions/csv/204-csv/286.csv
# processing file: WikiTableQuestions/csv/204-csv/287.csv
# processing file: WikiTableQuestions/csv/204-csv/288.csv
# processing file: WikiTableQuestions/csv/204-csv/289.csv
# processing file: WikiTableQuestions/csv/204-csv/29.csv
# processing file: WikiTableQuestions/csv/204-csv/290.csv
# processing file: WikiTableQuestions/csv/204-csv/291.csv
# processing file: WikiTableQuestions/csv/204-csv/292.csv
# processing file: WikiTableQuestions/csv/204-csv/293.csv
# processing file: WikiTableQuestions/csv/204-csv/294.csv
# processing file: WikiTableQuestions/csv/204-csv/295.csv
# processing file: WikiTableQuestions/csv/204-csv/296.csv
# processing file: WikiTableQuestions/csv/204-csv/297.csv
# processing file: WikiTableQuestions/csv/204-csv/298.csv
# processing file: WikiTableQuestions/csv/204-csv/299.csv
# processing file: WikiTableQuestions/csv/204-csv/3.csv
# processing file: WikiTableQuestions/csv/204-csv/30.csv
# processing file: WikiTableQuestions/csv/204-csv/300.csv
# processing file: WikiTableQuestions/csv/204-csv/301.csv
# processing file: WikiTableQuestions/csv/204-csv/302.csv
# processing file: WikiTableQuestions/csv/204-csv/303.csv
# processing file: WikiTableQuestions/csv/204-csv/304.csv
# processing file: WikiTableQuestions/csv/204-csv/305.csv
# processing file: WikiTableQuestions/csv/204-csv/306.csv
# processing file: WikiTableQuestions/csv/204-csv/307.csv
# processing file: WikiTableQuestions/csv/204-csv/308.csv
# processing file: WikiTableQuestions/csv/204-csv/309.csv
# processing file: WikiTableQuestions/csv/204-csv/31.csv
# processing file: WikiTableQuestions/csv/204-csv/310.csv
# processing file: WikiTableQuestions/csv/204-csv/311.csv
# processing file: WikiTableQuestions/csv/204-csv/312.csv
# processing file: WikiTableQuestions/csv/204-csv/313.csv
# processing file: WikiTableQuestions/csv/204-csv/314.csv
# processing file: WikiTableQuestions/csv/204-csv/315.csv
# processing file: WikiTableQuestions/csv/204-csv/316.csv
# processing file: WikiTableQuestions/csv/204-csv/317.csv
# processing file: WikiTableQuestions/csv/204-csv/318.csv
# processing file: WikiTableQuestions/csv/204-csv/319.csv
# processing file: WikiTableQuestions/csv/204-csv/32.csv
# processing file: WikiTableQuestions/csv/204-csv/320.csv
# processing file: WikiTableQuestions/csv/204-csv/321.csv
# processing file: WikiTableQuestions/csv/204-csv/322.csv
# processing file: WikiTableQuestions/csv/204-csv/323.csv
# processing file: WikiTableQuestions/csv/204-csv/324.csv
# processing file: WikiTableQuestions/csv/204-csv/325.csv
# processing file: WikiTableQuestions/csv/204-csv/326.csv
# processing file: WikiTableQuestions/csv/204-csv/327.csv
# processing file: WikiTableQuestions/csv/204-csv/328.csv
# processing file: WikiTableQuestions/csv/204-csv/329.csv
# processing file: WikiTableQuestions/csv/204-csv/33.csv
# processing file: WikiTableQuestions/csv/204-csv/330.csv
# processing file: WikiTableQuestions/csv/204-csv/331.csv
# processing file: WikiTableQuestions/csv/204-csv/332.csv
# processing file: WikiTableQuestions/csv/204-csv/333.csv
# processing file: WikiTableQuestions/csv/204-csv/334.csv
# processing file: WikiTableQuestions/csv/204-csv/335.csv
# processing file: WikiTableQuestions/csv/204-csv/336.csv
# processing file: WikiTableQuestions/csv/204-csv/337.csv
# processing file: WikiTableQuestions/csv/204-csv/338.csv
# processing file: WikiTableQuestions/csv/204-csv/339.csv
# processing file: WikiTableQuestions/csv/204-csv/34.csv
# processing file: WikiTableQuestions/csv/204-csv/340.csv
# processing file: WikiTableQuestions/csv/204-csv/341.csv
# processing file: WikiTableQuestions/csv/204-csv/342.csv
# processing file: WikiTableQuestions/csv/204-csv/343.csv
# processing file: WikiTableQuestions/csv/204-csv/344.csv
# processing file: WikiTableQuestions/csv/204-csv/345.csv
# processing file: WikiTableQuestions/csv/204-csv/346.csv
# processing file: WikiTableQuestions/csv/204-csv/347.csv
# processing file: WikiTableQuestions/csv/204-csv/348.csv
# processing file: WikiTableQuestions/csv/204-csv/349.csv
# processing file: WikiTableQuestions/csv/204-csv/35.csv
# processing file: WikiTableQuestions/csv/204-csv/350.csv
# processing file: WikiTableQuestions/csv/204-csv/351.csv
# processing file: WikiTableQuestions/csv/204-csv/352.csv
# processing file: WikiTableQuestions/csv/204-csv/353.csv
# processing file: WikiTableQuestions/csv/204-csv/354.csv
# processing file: WikiTableQuestions/csv/204-csv/355.csv
# processing file: WikiTableQuestions/csv/204-csv/356.csv
# processing file: WikiTableQuestions/csv/204-csv/357.csv
# processing file: WikiTableQuestions/csv/204-csv/358.csv
# processing file: WikiTableQuestions/csv/204-csv/359.csv
# processing file: WikiTableQuestions/csv/204-csv/36.csv
# processing file: WikiTableQuestions/csv/204-csv/360.csv
# processing file: WikiTableQuestions/csv/204-csv/361.csv
# processing file: WikiTableQuestions/csv/204-csv/362.csv
# processing file: WikiTableQuestions/csv/204-csv/363.csv
# processing file: WikiTableQuestions/csv/204-csv/364.csv
# processing file: WikiTableQuestions/csv/204-csv/365.csv
# processing file: WikiTableQuestions/csv/204-csv/366.csv
# processing file: WikiTableQuestions/csv/204-csv/367.csv
# processing file: WikiTableQuestions/csv/204-csv/368.csv
# processing file: WikiTableQuestions/csv/204-csv/369.csv
# processing file: WikiTableQuestions/csv/204-csv/37.csv
# processing file: WikiTableQuestions/csv/204-csv/370.csv
# processing file: WikiTableQuestions/csv/204-csv/371.csv
# processing file: WikiTableQuestions/csv/204-csv/372.csv
# processing file: WikiTableQuestions/csv/204-csv/373.csv
# processing file: WikiTableQuestions/csv/204-csv/374.csv
# processing file: WikiTableQuestions/csv/204-csv/375.csv
# processing file: WikiTableQuestions/csv/204-csv/376.csv
# processing file: WikiTableQuestions/csv/204-csv/377.csv
# processing file: WikiTableQuestions/csv/204-csv/378.csv
# processing file: WikiTableQuestions/csv/204-csv/379.csv
# processing file: WikiTableQuestions/csv/204-csv/38.csv
# processing file: WikiTableQuestions/csv/204-csv/380.csv
# processing file: WikiTableQuestions/csv/204-csv/381.csv
# processing file: WikiTableQuestions/csv/204-csv/382.csv
# processing file: WikiTableQuestions/csv/204-csv/383.csv
# processing file: WikiTableQuestions/csv/204-csv/384.csv
# processing file: WikiTableQuestions/csv/204-csv/385.csv
# processing file: WikiTableQuestions/csv/204-csv/386.csv
# processing file: WikiTableQuestions/csv/204-csv/387.csv
# processing file: WikiTableQuestions/csv/204-csv/388.csv
# processing file: WikiTableQuestions/csv/204-csv/389.csv
# processing file: WikiTableQuestions/csv/204-csv/39.csv
# processing file: WikiTableQuestions/csv/204-csv/390.csv
# processing file: WikiTableQuestions/csv/204-csv/391.csv
# processing file: WikiTableQuestions/csv/204-csv/392.csv
# processing file: WikiTableQuestions/csv/204-csv/393.csv
# processing file: WikiTableQuestions/csv/204-csv/394.csv
# processing file: WikiTableQuestions/csv/204-csv/395.csv
# processing file: WikiTableQuestions/csv/204-csv/396.csv
# processing file: WikiTableQuestions/csv/204-csv/397.csv
# processing file: WikiTableQuestions/csv/204-csv/398.csv
# processing file: WikiTableQuestions/csv/204-csv/399.csv
# processing file: WikiTableQuestions/csv/204-csv/4.csv
# processing file: WikiTableQuestions/csv/204-csv/40.csv
# processing file: WikiTableQuestions/csv/204-csv/400.csv
# processing file: WikiTableQuestions/csv/204-csv/401.csv
# processing file: WikiTableQuestions/csv/204-csv/402.csv
# processing file: WikiTableQuestions/csv/204-csv/403.csv
# processing file: WikiTableQuestions/csv/204-csv/404.csv
# processing file: WikiTableQuestions/csv/204-csv/405.csv
# processing file: WikiTableQuestions/csv/204-csv/406.csv
# processing file: WikiTableQuestions/csv/204-csv/407.csv
# processing file: WikiTableQuestions/csv/204-csv/408.csv
# processing file: WikiTableQuestions/csv/204-csv/409.csv
# processing file: WikiTableQuestions/csv/204-csv/41.csv
# processing file: WikiTableQuestions/csv/204-csv/410.csv
# processing file: WikiTableQuestions/csv/204-csv/411.csv
# processing file: WikiTableQuestions/csv/204-csv/412.csv
# processing file: WikiTableQuestions/csv/204-csv/413.csv
# processing file: WikiTableQuestions/csv/204-csv/414.csv
# processing file: WikiTableQuestions/csv/204-csv/415.csv
# processing file: WikiTableQuestions/csv/204-csv/416.csv
# processing file: WikiTableQuestions/csv/204-csv/417.csv
# processing file: WikiTableQuestions/csv/204-csv/418.csv
# processing file: WikiTableQuestions/csv/204-csv/419.csv
# processing file: WikiTableQuestions/csv/204-csv/42.csv
# processing file: WikiTableQuestions/csv/204-csv/420.csv
# Error parsing WikiTableQuestions/csv/204-csv/420.csv: Error tokenizing data. C error: Expected 6 fields in line 12, saw 9
#
# processing file: WikiTableQuestions/csv/204-csv/421.csv
# processing file: WikiTableQuestions/csv/204-csv/422.csv
# processing file: WikiTableQuestions/csv/204-csv/423.csv
# processing file: WikiTableQuestions/csv/204-csv/424.csv
# processing file: WikiTableQuestions/csv/204-csv/425.csv
# processing file: WikiTableQuestions/csv/204-csv/426.csv
# processing file: WikiTableQuestions/csv/204-csv/427.csv
# processing file: WikiTableQuestions/csv/204-csv/428.csv
# processing file: WikiTableQuestions/csv/204-csv/429.csv
# Error parsing WikiTableQuestions/csv/204-csv/429.csv: Error tokenizing data. C error: Expected 5 fields in line 5, saw 9
#
# processing file: WikiTableQuestions/csv/204-csv/43.csv
# processing file: WikiTableQuestions/csv/204-csv/430.csv
# processing file: WikiTableQuestions/csv/204-csv/431.csv
# processing file: WikiTableQuestions/csv/204-csv/432.csv
# processing file: WikiTableQuestions/csv/204-csv/433.csv
# processing file: WikiTableQuestions/csv/204-csv/434.csv
# processing file: WikiTableQuestions/csv/204-csv/435.csv
# processing file: WikiTableQuestions/csv/204-csv/436.csv
# processing file: WikiTableQuestions/csv/204-csv/437.csv
# processing file: WikiTableQuestions/csv/204-csv/438.csv
# Error parsing WikiTableQuestions/csv/204-csv/438.csv: Error tokenizing data. C error: Expected 6 fields in line 3, saw 7
#
# processing file: WikiTableQuestions/csv/204-csv/439.csv
# processing file: WikiTableQuestions/csv/204-csv/44.csv
# processing file: WikiTableQuestions/csv/204-csv/440.csv
# processing file: WikiTableQuestions/csv/204-csv/441.csv
# processing file: WikiTableQuestions/csv/204-csv/442.csv
# processing file: WikiTableQuestions/csv/204-csv/443.csv
# processing file: WikiTableQuestions/csv/204-csv/444.csv
# processing file: WikiTableQuestions/csv/204-csv/445.csv
# processing file: WikiTableQuestions/csv/204-csv/446.csv
# processing file: WikiTableQuestions/csv/204-csv/447.csv
# processing file: WikiTableQuestions/csv/204-csv/448.csv
# processing file: WikiTableQuestions/csv/204-csv/449.csv
# Error parsing WikiTableQuestions/csv/204-csv/449.csv: Error tokenizing data. C error: Expected 5 fields in line 4, saw 6
#
# processing file: WikiTableQuestions/csv/204-csv/45.csv
# processing file: WikiTableQuestions/csv/204-csv/450.csv
# processing file: WikiTableQuestions/csv/204-csv/451.csv
# processing file: WikiTableQuestions/csv/204-csv/452.csv
# processing file: WikiTableQuestions/csv/204-csv/453.csv
# Error parsing WikiTableQuestions/csv/204-csv/453.csv: Error tokenizing data. C error: Expected 7 fields in line 3, saw 10
#
# processing file: WikiTableQuestions/csv/204-csv/454.csv
# processing file: WikiTableQuestions/csv/204-csv/455.csv
# processing file: WikiTableQuestions/csv/204-csv/456.csv
# processing file: WikiTableQuestions/csv/204-csv/457.csv
# processing file: WikiTableQuestions/csv/204-csv/458.csv
# processing file: WikiTableQuestions/csv/204-csv/459.csv
# processing file: WikiTableQuestions/csv/204-csv/46.csv
# processing file: WikiTableQuestions/csv/204-csv/460.csv
# processing file: WikiTableQuestions/csv/204-csv/461.csv
# processing file: WikiTableQuestions/csv/204-csv/462.csv
# processing file: WikiTableQuestions/csv/204-csv/463.csv
# processing file: WikiTableQuestions/csv/204-csv/464.csv
# processing file: WikiTableQuestions/csv/204-csv/465.csv
# processing file: WikiTableQuestions/csv/204-csv/466.csv
# processing file: WikiTableQuestions/csv/204-csv/467.csv
# processing file: WikiTableQuestions/csv/204-csv/468.csv
# processing file: WikiTableQuestions/csv/204-csv/469.csv
# processing file: WikiTableQuestions/csv/204-csv/47.csv
# processing file: WikiTableQuestions/csv/204-csv/470.csv
# processing file: WikiTableQuestions/csv/204-csv/471.csv
# processing file: WikiTableQuestions/csv/204-csv/472.csv
# processing file: WikiTableQuestions/csv/204-csv/473.csv
# processing file: WikiTableQuestions/csv/204-csv/474.csv
# processing file: WikiTableQuestions/csv/204-csv/475.csv
# processing file: WikiTableQuestions/csv/204-csv/476.csv
# processing file: WikiTableQuestions/csv/204-csv/477.csv
# processing file: WikiTableQuestions/csv/204-csv/478.csv
# processing file: WikiTableQuestions/csv/204-csv/479.csv
# processing file: WikiTableQuestions/csv/204-csv/48.csv
# processing file: WikiTableQuestions/csv/204-csv/480.csv
# processing file: WikiTableQuestions/csv/204-csv/481.csv
# processing file: WikiTableQuestions/csv/204-csv/482.csv
# processing file: WikiTableQuestions/csv/204-csv/483.csv
# processing file: WikiTableQuestions/csv/204-csv/484.csv
# processing file: WikiTableQuestions/csv/204-csv/485.csv
# processing file: WikiTableQuestions/csv/204-csv/486.csv
# processing file: WikiTableQuestions/csv/204-csv/487.csv
# processing file: WikiTableQuestions/csv/204-csv/488.csv
# processing file: WikiTableQuestions/csv/204-csv/489.csv
# processing file: WikiTableQuestions/csv/204-csv/49.csv
# processing file: WikiTableQuestions/csv/204-csv/490.csv
# processing file: WikiTableQuestions/csv/204-csv/491.csv
# processing file: WikiTableQuestions/csv/204-csv/492.csv
# processing file: WikiTableQuestions/csv/204-csv/493.csv
# processing file: WikiTableQuestions/csv/204-csv/494.csv
# processing file: WikiTableQuestions/csv/204-csv/495.csv
# processing file: WikiTableQuestions/csv/204-csv/496.csv
# processing file: WikiTableQuestions/csv/204-csv/497.csv
# processing file: WikiTableQuestions/csv/204-csv/498.csv
# processing file: WikiTableQuestions/csv/204-csv/499.csv
# processing file: WikiTableQuestions/csv/204-csv/5.csv
# Error parsing WikiTableQuestions/csv/204-csv/5.csv: Error tokenizing data. C error: Expected 5 fields in line 8, saw 13
#
# processing file: WikiTableQuestions/csv/204-csv/50.csv
# Error parsing WikiTableQuestions/csv/204-csv/50.csv: Error tokenizing data. C error: Expected 8 fields in line 5, saw 9
#
# processing file: WikiTableQuestions/csv/204-csv/500.csv
# processing file: WikiTableQuestions/csv/204-csv/501.csv
# processing file: WikiTableQuestions/csv/204-csv/502.csv
# processing file: WikiTableQuestions/csv/204-csv/503.csv
# processing file: WikiTableQuestions/csv/204-csv/504.csv
# processing file: WikiTableQuestions/csv/204-csv/505.csv
# processing file: WikiTableQuestions/csv/204-csv/506.csv
# processing file: WikiTableQuestions/csv/204-csv/507.csv
# processing file: WikiTableQuestions/csv/204-csv/508.csv
# processing file: WikiTableQuestions/csv/204-csv/509.csv
# processing file: WikiTableQuestions/csv/204-csv/51.csv
# processing file: WikiTableQuestions/csv/204-csv/510.csv
# processing file: WikiTableQuestions/csv/204-csv/511.csv
# processing file: WikiTableQuestions/csv/204-csv/512.csv
# processing file: WikiTableQuestions/csv/204-csv/513.csv
# processing file: WikiTableQuestions/csv/204-csv/514.csv
# processing file: WikiTableQuestions/csv/204-csv/515.csv
# processing file: WikiTableQuestions/csv/204-csv/516.csv
# processing file: WikiTableQuestions/csv/204-csv/517.csv
# processing file: WikiTableQuestions/csv/204-csv/518.csv
# processing file: WikiTableQuestions/csv/204-csv/519.csv
# processing file: WikiTableQuestions/csv/204-csv/52.csv
# processing file: WikiTableQuestions/csv/204-csv/520.csv
# processing file: WikiTableQuestions/csv/204-csv/521.csv
# processing file: WikiTableQuestions/csv/204-csv/522.csv
# processing file: WikiTableQuestions/csv/204-csv/523.csv
# processing file: WikiTableQuestions/csv/204-csv/524.csv
# processing file: WikiTableQuestions/csv/204-csv/525.csv
# processing file: WikiTableQuestions/csv/204-csv/526.csv
# processing file: WikiTableQuestions/csv/204-csv/528.csv
# processing file: WikiTableQuestions/csv/204-csv/529.csv
# processing file: WikiTableQuestions/csv/204-csv/53.csv
# Error parsing WikiTableQuestions/csv/204-csv/53.csv: Error tokenizing data. C error: Expected 8 fields in line 7, saw 9
#
# processing file: WikiTableQuestions/csv/204-csv/530.csv
# processing file: WikiTableQuestions/csv/204-csv/531.csv
# processing file: WikiTableQuestions/csv/204-csv/532.csv
# processing file: WikiTableQuestions/csv/204-csv/533.csv
# processing file: WikiTableQuestions/csv/204-csv/534.csv
# processing file: WikiTableQuestions/csv/204-csv/535.csv
# processing file: WikiTableQuestions/csv/204-csv/536.csv
# processing file: WikiTableQuestions/csv/204-csv/537.csv
# processing file: WikiTableQuestions/csv/204-csv/538.csv
# processing file: WikiTableQuestions/csv/204-csv/539.csv
# processing file: WikiTableQuestions/csv/204-csv/54.csv
# processing file: WikiTableQuestions/csv/204-csv/540.csv
# processing file: WikiTableQuestions/csv/204-csv/541.csv
# processing file: WikiTableQuestions/csv/204-csv/542.csv
# processing file: WikiTableQuestions/csv/204-csv/543.csv
# processing file: WikiTableQuestions/csv/204-csv/544.csv
# processing file: WikiTableQuestions/csv/204-csv/545.csv
# processing file: WikiTableQuestions/csv/204-csv/546.csv
# processing file: WikiTableQuestions/csv/204-csv/547.csv
# processing file: WikiTableQuestions/csv/204-csv/548.csv
# processing file: WikiTableQuestions/csv/204-csv/549.csv
# Error parsing WikiTableQuestions/csv/204-csv/549.csv: Error tokenizing data. C error: Expected 10 fields in line 21, saw 11
#
# processing file: WikiTableQuestions/csv/204-csv/55.csv
# processing file: WikiTableQuestions/csv/204-csv/550.csv
# processing file: WikiTableQuestions/csv/204-csv/551.csv
# processing file: WikiTableQuestions/csv/204-csv/552.csv
# processing file: WikiTableQuestions/csv/204-csv/553.csv
# processing file: WikiTableQuestions/csv/204-csv/554.csv
# processing file: WikiTableQuestions/csv/204-csv/555.csv
# processing file: WikiTableQuestions/csv/204-csv/556.csv
# processing file: WikiTableQuestions/csv/204-csv/557.csv
# processing file: WikiTableQuestions/csv/204-csv/558.csv
# processing file: WikiTableQuestions/csv/204-csv/559.csv
# processing file: WikiTableQuestions/csv/204-csv/56.csv
# processing file: WikiTableQuestions/csv/204-csv/560.csv
# processing file: WikiTableQuestions/csv/204-csv/561.csv
# processing file: WikiTableQuestions/csv/204-csv/562.csv
# processing file: WikiTableQuestions/csv/204-csv/563.csv
# processing file: WikiTableQuestions/csv/204-csv/564.csv
# processing file: WikiTableQuestions/csv/204-csv/565.csv
# processing file: WikiTableQuestions/csv/204-csv/566.csv
# processing file: WikiTableQuestions/csv/204-csv/567.csv
# processing file: WikiTableQuestions/csv/204-csv/568.csv
# processing file: WikiTableQuestions/csv/204-csv/569.csv
# processing file: WikiTableQuestions/csv/204-csv/57.csv
# processing file: WikiTableQuestions/csv/204-csv/570.csv
# processing file: WikiTableQuestions/csv/204-csv/571.csv
# processing file: WikiTableQuestions/csv/204-csv/572.csv
# processing file: WikiTableQuestions/csv/204-csv/573.csv
# processing file: WikiTableQuestions/csv/204-csv/574.csv
# Error parsing WikiTableQuestions/csv/204-csv/574.csv: Error tokenizing data. C error: Expected 6 fields in line 3, saw 7
#
# processing file: WikiTableQuestions/csv/204-csv/575.csv
# processing file: WikiTableQuestions/csv/204-csv/576.csv
# processing file: WikiTableQuestions/csv/204-csv/577.csv
# processing file: WikiTableQuestions/csv/204-csv/578.csv
# processing file: WikiTableQuestions/csv/204-csv/579.csv
# processing file: WikiTableQuestions/csv/204-csv/58.csv
# processing file: WikiTableQuestions/csv/204-csv/580.csv
# processing file: WikiTableQuestions/csv/204-csv/581.csv
# processing file: WikiTableQuestions/csv/204-csv/582.csv
# processing file: WikiTableQuestions/csv/204-csv/583.csv
# processing file: WikiTableQuestions/csv/204-csv/584.csv
# processing file: WikiTableQuestions/csv/204-csv/585.csv
# processing file: WikiTableQuestions/csv/204-csv/586.csv
# processing file: WikiTableQuestions/csv/204-csv/587.csv
# processing file: WikiTableQuestions/csv/204-csv/588.csv
# processing file: WikiTableQuestions/csv/204-csv/589.csv
# processing file: WikiTableQuestions/csv/204-csv/59.csv
# processing file: WikiTableQuestions/csv/204-csv/590.csv
# processing file: WikiTableQuestions/csv/204-csv/591.csv
# processing file: WikiTableQuestions/csv/204-csv/592.csv
# processing file: WikiTableQuestions/csv/204-csv/593.csv
# processing file: WikiTableQuestions/csv/204-csv/594.csv
# processing file: WikiTableQuestions/csv/204-csv/595.csv
# processing file: WikiTableQuestions/csv/204-csv/596.csv
# processing file: WikiTableQuestions/csv/204-csv/597.csv
# processing file: WikiTableQuestions/csv/204-csv/598.csv
# processing file: WikiTableQuestions/csv/204-csv/599.csv
# processing file: WikiTableQuestions/csv/204-csv/6.csv
# processing file: WikiTableQuestions/csv/204-csv/60.csv
# processing file: WikiTableQuestions/csv/204-csv/600.csv
# processing file: WikiTableQuestions/csv/204-csv/601.csv
# processing file: WikiTableQuestions/csv/204-csv/602.csv
# processing file: WikiTableQuestions/csv/204-csv/603.csv
# processing file: WikiTableQuestions/csv/204-csv/604.csv
# processing file: WikiTableQuestions/csv/204-csv/605.csv
# processing file: WikiTableQuestions/csv/204-csv/606.csv
# processing file: WikiTableQuestions/csv/204-csv/607.csv
# processing file: WikiTableQuestions/csv/204-csv/608.csv
# processing file: WikiTableQuestions/csv/204-csv/609.csv
# processing file: WikiTableQuestions/csv/204-csv/61.csv
# processing file: WikiTableQuestions/csv/204-csv/610.csv
# processing file: WikiTableQuestions/csv/204-csv/611.csv
# processing file: WikiTableQuestions/csv/204-csv/612.csv
# processing file: WikiTableQuestions/csv/204-csv/613.csv
# Error parsing WikiTableQuestions/csv/204-csv/613.csv: Error tokenizing data. C error: Expected 6 fields in line 5, saw 10
#
# processing file: WikiTableQuestions/csv/204-csv/614.csv
# processing file: WikiTableQuestions/csv/204-csv/615.csv
# processing file: WikiTableQuestions/csv/204-csv/616.csv
# processing file: WikiTableQuestions/csv/204-csv/617.csv
# processing file: WikiTableQuestions/csv/204-csv/618.csv
# processing file: WikiTableQuestions/csv/204-csv/619.csv
# processing file: WikiTableQuestions/csv/204-csv/62.csv
# processing file: WikiTableQuestions/csv/204-csv/620.csv
# processing file: WikiTableQuestions/csv/204-csv/621.csv
# processing file: WikiTableQuestions/csv/204-csv/622.csv
# processing file: WikiTableQuestions/csv/204-csv/623.csv
# processing file: WikiTableQuestions/csv/204-csv/624.csv
# processing file: WikiTableQuestions/csv/204-csv/625.csv
# processing file: WikiTableQuestions/csv/204-csv/626.csv
# processing file: WikiTableQuestions/csv/204-csv/627.csv
# processing file: WikiTableQuestions/csv/204-csv/628.csv
# processing file: WikiTableQuestions/csv/204-csv/629.csv
# processing file: WikiTableQuestions/csv/204-csv/63.csv
# processing file: WikiTableQuestions/csv/204-csv/630.csv
# processing file: WikiTableQuestions/csv/204-csv/631.csv
# processing file: WikiTableQuestions/csv/204-csv/632.csv
# processing file: WikiTableQuestions/csv/204-csv/633.csv
# processing file: WikiTableQuestions/csv/204-csv/634.csv
# processing file: WikiTableQuestions/csv/204-csv/635.csv
# processing file: WikiTableQuestions/csv/204-csv/636.csv
# processing file: WikiTableQuestions/csv/204-csv/637.csv
# processing file: WikiTableQuestions/csv/204-csv/638.csv
# processing file: WikiTableQuestions/csv/204-csv/639.csv
# processing file: WikiTableQuestions/csv/204-csv/64.csv
# processing file: WikiTableQuestions/csv/204-csv/640.csv
# processing file: WikiTableQuestions/csv/204-csv/641.csv
# processing file: WikiTableQuestions/csv/204-csv/642.csv
# processing file: WikiTableQuestions/csv/204-csv/643.csv
# processing file: WikiTableQuestions/csv/204-csv/644.csv
# processing file: WikiTableQuestions/csv/204-csv/645.csv
# processing file: WikiTableQuestions/csv/204-csv/646.csv
# processing file: WikiTableQuestions/csv/204-csv/647.csv
# processing file: WikiTableQuestions/csv/204-csv/648.csv
# processing file: WikiTableQuestions/csv/204-csv/649.csv
# processing file: WikiTableQuestions/csv/204-csv/65.csv
# processing file: WikiTableQuestions/csv/204-csv/650.csv
# processing file: WikiTableQuestions/csv/204-csv/651.csv
# processing file: WikiTableQuestions/csv/204-csv/652.csv
# processing file: WikiTableQuestions/csv/204-csv/653.csv
# processing file: WikiTableQuestions/csv/204-csv/654.csv
# processing file: WikiTableQuestions/csv/204-csv/655.csv
# processing file: WikiTableQuestions/csv/204-csv/656.csv
# processing file: WikiTableQuestions/csv/204-csv/657.csv
# processing file: WikiTableQuestions/csv/204-csv/658.csv
# processing file: WikiTableQuestions/csv/204-csv/659.csv
# processing file: WikiTableQuestions/csv/204-csv/66.csv
# processing file: WikiTableQuestions/csv/204-csv/660.csv
# processing file: WikiTableQuestions/csv/204-csv/661.csv
# processing file: WikiTableQuestions/csv/204-csv/662.csv
# processing file: WikiTableQuestions/csv/204-csv/663.csv
# processing file: WikiTableQuestions/csv/204-csv/664.csv
# processing file: WikiTableQuestions/csv/204-csv/665.csv
# processing file: WikiTableQuestions/csv/204-csv/666.csv
# processing file: WikiTableQuestions/csv/204-csv/667.csv
# processing file: WikiTableQuestions/csv/204-csv/668.csv
# processing file: WikiTableQuestions/csv/204-csv/669.csv
# processing file: WikiTableQuestions/csv/204-csv/67.csv
# processing file: WikiTableQuestions/csv/204-csv/670.csv
# processing file: WikiTableQuestions/csv/204-csv/671.csv
# processing file: WikiTableQuestions/csv/204-csv/672.csv
# processing file: WikiTableQuestions/csv/204-csv/673.csv
# processing file: WikiTableQuestions/csv/204-csv/674.csv
# processing file: WikiTableQuestions/csv/204-csv/675.csv
# processing file: WikiTableQuestions/csv/204-csv/676.csv
# processing file: WikiTableQuestions/csv/204-csv/677.csv
# processing file: WikiTableQuestions/csv/204-csv/678.csv
# processing file: WikiTableQuestions/csv/204-csv/679.csv
# processing file: WikiTableQuestions/csv/204-csv/68.csv
# processing file: WikiTableQuestions/csv/204-csv/680.csv
# processing file: WikiTableQuestions/csv/204-csv/681.csv
# processing file: WikiTableQuestions/csv/204-csv/682.csv
# processing file: WikiTableQuestions/csv/204-csv/683.csv
# processing file: WikiTableQuestions/csv/204-csv/684.csv
# processing file: WikiTableQuestions/csv/204-csv/685.csv
# processing file: WikiTableQuestions/csv/204-csv/686.csv
# processing file: WikiTableQuestions/csv/204-csv/687.csv
# processing file: WikiTableQuestions/csv/204-csv/688.csv
# processing file: WikiTableQuestions/csv/204-csv/689.csv
# processing file: WikiTableQuestions/csv/204-csv/69.csv
# Error parsing WikiTableQuestions/csv/204-csv/69.csv: Error tokenizing data. C error: Expected 6 fields in line 88, saw 7
#
# processing file: WikiTableQuestions/csv/204-csv/690.csv
# processing file: WikiTableQuestions/csv/204-csv/691.csv
# processing file: WikiTableQuestions/csv/204-csv/692.csv
# processing file: WikiTableQuestions/csv/204-csv/693.csv
# processing file: WikiTableQuestions/csv/204-csv/694.csv
# processing file: WikiTableQuestions/csv/204-csv/695.csv
# processing file: WikiTableQuestions/csv/204-csv/696.csv
# processing file: WikiTableQuestions/csv/204-csv/697.csv
# Error parsing WikiTableQuestions/csv/204-csv/697.csv: Error tokenizing data. C error: Expected 6 fields in line 34, saw 7
#
# processing file: WikiTableQuestions/csv/204-csv/698.csv
# processing file: WikiTableQuestions/csv/204-csv/699.csv
# processing file: WikiTableQuestions/csv/204-csv/7.csv
# processing file: WikiTableQuestions/csv/204-csv/70.csv
# processing file: WikiTableQuestions/csv/204-csv/700.csv
# processing file: WikiTableQuestions/csv/204-csv/701.csv
# processing file: WikiTableQuestions/csv/204-csv/702.csv
# processing file: WikiTableQuestions/csv/204-csv/703.csv
# processing file: WikiTableQuestions/csv/204-csv/704.csv
# processing file: WikiTableQuestions/csv/204-csv/705.csv
# processing file: WikiTableQuestions/csv/204-csv/706.csv
# processing file: WikiTableQuestions/csv/204-csv/707.csv
# processing file: WikiTableQuestions/csv/204-csv/708.csv
# Error parsing WikiTableQuestions/csv/204-csv/708.csv: Error tokenizing data. C error: Expected 8 fields in line 6, saw 12
#
# processing file: WikiTableQuestions/csv/204-csv/709.csv
# Error parsing WikiTableQuestions/csv/204-csv/709.csv: Error tokenizing data. C error: Expected 6 fields in line 9, saw 7
#
# processing file: WikiTableQuestions/csv/204-csv/71.csv
# processing file: WikiTableQuestions/csv/204-csv/710.csv
# processing file: WikiTableQuestions/csv/204-csv/711.csv
# processing file: WikiTableQuestions/csv/204-csv/712.csv
# processing file: WikiTableQuestions/csv/204-csv/713.csv
# processing file: WikiTableQuestions/csv/204-csv/714.csv
# processing file: WikiTableQuestions/csv/204-csv/715.csv
# processing file: WikiTableQuestions/csv/204-csv/716.csv
# processing file: WikiTableQuestions/csv/204-csv/717.csv
# processing file: WikiTableQuestions/csv/204-csv/718.csv
# processing file: WikiTableQuestions/csv/204-csv/719.csv
# processing file: WikiTableQuestions/csv/204-csv/72.csv
# processing file: WikiTableQuestions/csv/204-csv/720.csv
# processing file: WikiTableQuestions/csv/204-csv/721.csv
# processing file: WikiTableQuestions/csv/204-csv/722.csv
# processing file: WikiTableQuestions/csv/204-csv/723.csv
# processing file: WikiTableQuestions/csv/204-csv/724.csv
# processing file: WikiTableQuestions/csv/204-csv/725.csv
# processing file: WikiTableQuestions/csv/204-csv/726.csv
# processing file: WikiTableQuestions/csv/204-csv/727.csv
# processing file: WikiTableQuestions/csv/204-csv/728.csv
# processing file: WikiTableQuestions/csv/204-csv/729.csv
# processing file: WikiTableQuestions/csv/204-csv/73.csv
# processing file: WikiTableQuestions/csv/204-csv/730.csv
# processing file: WikiTableQuestions/csv/204-csv/731.csv
# processing file: WikiTableQuestions/csv/204-csv/732.csv
# processing file: WikiTableQuestions/csv/204-csv/733.csv
# processing file: WikiTableQuestions/csv/204-csv/734.csv
# processing file: WikiTableQuestions/csv/204-csv/735.csv
# processing file: WikiTableQuestions/csv/204-csv/736.csv
# processing file: WikiTableQuestions/csv/204-csv/737.csv
# processing file: WikiTableQuestions/csv/204-csv/738.csv
# processing file: WikiTableQuestions/csv/204-csv/739.csv
# processing file: WikiTableQuestions/csv/204-csv/74.csv
# processing file: WikiTableQuestions/csv/204-csv/740.csv
# processing file: WikiTableQuestions/csv/204-csv/741.csv
# processing file: WikiTableQuestions/csv/204-csv/742.csv
# processing file: WikiTableQuestions/csv/204-csv/743.csv
# processing file: WikiTableQuestions/csv/204-csv/744.csv
# processing file: WikiTableQuestions/csv/204-csv/745.csv
# processing file: WikiTableQuestions/csv/204-csv/746.csv
# processing file: WikiTableQuestions/csv/204-csv/747.csv
# processing file: WikiTableQuestions/csv/204-csv/748.csv
# processing file: WikiTableQuestions/csv/204-csv/749.csv
# processing file: WikiTableQuestions/csv/204-csv/75.csv
# processing file: WikiTableQuestions/csv/204-csv/750.csv
# processing file: WikiTableQuestions/csv/204-csv/751.csv
# processing file: WikiTableQuestions/csv/204-csv/752.csv
# processing file: WikiTableQuestions/csv/204-csv/753.csv
# processing file: WikiTableQuestions/csv/204-csv/754.csv
# processing file: WikiTableQuestions/csv/204-csv/755.csv
# processing file: WikiTableQuestions/csv/204-csv/756.csv
# processing file: WikiTableQuestions/csv/204-csv/757.csv
# processing file: WikiTableQuestions/csv/204-csv/758.csv
# processing file: WikiTableQuestions/csv/204-csv/759.csv
# processing file: WikiTableQuestions/csv/204-csv/76.csv
# processing file: WikiTableQuestions/csv/204-csv/760.csv
# processing file: WikiTableQuestions/csv/204-csv/761.csv
# processing file: WikiTableQuestions/csv/204-csv/762.csv
# processing file: WikiTableQuestions/csv/204-csv/763.csv
# processing file: WikiTableQuestions/csv/204-csv/764.csv
# processing file: WikiTableQuestions/csv/204-csv/765.csv
# processing file: WikiTableQuestions/csv/204-csv/766.csv
# processing file: WikiTableQuestions/csv/204-csv/767.csv
# processing file: WikiTableQuestions/csv/204-csv/768.csv
# processing file: WikiTableQuestions/csv/204-csv/769.csv
# processing file: WikiTableQuestions/csv/204-csv/77.csv
# processing file: WikiTableQuestions/csv/204-csv/770.csv
# processing file: WikiTableQuestions/csv/204-csv/771.csv
# processing file: WikiTableQuestions/csv/204-csv/772.csv
# processing file: WikiTableQuestions/csv/204-csv/773.csv
# processing file: WikiTableQuestions/csv/204-csv/774.csv
# processing file: WikiTableQuestions/csv/204-csv/775.csv
# processing file: WikiTableQuestions/csv/204-csv/776.csv
# processing file: WikiTableQuestions/csv/204-csv/777.csv
# processing file: WikiTableQuestions/csv/204-csv/778.csv
# processing file: WikiTableQuestions/csv/204-csv/779.csv
# processing file: WikiTableQuestions/csv/204-csv/78.csv
# processing file: WikiTableQuestions/csv/204-csv/780.csv
# processing file: WikiTableQuestions/csv/204-csv/781.csv
# processing file: WikiTableQuestions/csv/204-csv/782.csv
# processing file: WikiTableQuestions/csv/204-csv/783.csv
# processing file: WikiTableQuestions/csv/204-csv/784.csv
# processing file: WikiTableQuestions/csv/204-csv/785.csv
# processing file: WikiTableQuestions/csv/204-csv/786.csv
# processing file: WikiTableQuestions/csv/204-csv/787.csv
# Error parsing WikiTableQuestions/csv/204-csv/787.csv: Error tokenizing data. C error: Expected 5 fields in line 10, saw 7
#
# processing file: WikiTableQuestions/csv/204-csv/788.csv
# processing file: WikiTableQuestions/csv/204-csv/789.csv
# processing file: WikiTableQuestions/csv/204-csv/79.csv
# processing file: WikiTableQuestions/csv/204-csv/790.csv
# processing file: WikiTableQuestions/csv/204-csv/791.csv
# processing file: WikiTableQuestions/csv/204-csv/792.csv
# processing file: WikiTableQuestions/csv/204-csv/793.csv
# processing file: WikiTableQuestions/csv/204-csv/794.csv
# processing file: WikiTableQuestions/csv/204-csv/795.csv
# processing file: WikiTableQuestions/csv/204-csv/796.csv
# processing file: WikiTableQuestions/csv/204-csv/797.csv
# processing file: WikiTableQuestions/csv/204-csv/798.csv
# processing file: WikiTableQuestions/csv/204-csv/799.csv
# processing file: WikiTableQuestions/csv/204-csv/8.csv
# processing file: WikiTableQuestions/csv/204-csv/80.csv
# processing file: WikiTableQuestions/csv/204-csv/800.csv
# processing file: WikiTableQuestions/csv/204-csv/801.csv
# processing file: WikiTableQuestions/csv/204-csv/802.csv
# processing file: WikiTableQuestions/csv/204-csv/803.csv
# processing file: WikiTableQuestions/csv/204-csv/804.csv
# processing file: WikiTableQuestions/csv/204-csv/805.csv
# processing file: WikiTableQuestions/csv/204-csv/806.csv
# processing file: WikiTableQuestions/csv/204-csv/807.csv
# processing file: WikiTableQuestions/csv/204-csv/808.csv
# processing file: WikiTableQuestions/csv/204-csv/809.csv
# processing file: WikiTableQuestions/csv/204-csv/81.csv
# processing file: WikiTableQuestions/csv/204-csv/810.csv
# processing file: WikiTableQuestions/csv/204-csv/811.csv
# processing file: WikiTableQuestions/csv/204-csv/812.csv
# processing file: WikiTableQuestions/csv/204-csv/813.csv
# processing file: WikiTableQuestions/csv/204-csv/814.csv
# processing file: WikiTableQuestions/csv/204-csv/815.csv
# processing file: WikiTableQuestions/csv/204-csv/816.csv
# processing file: WikiTableQuestions/csv/204-csv/817.csv
# processing file: WikiTableQuestions/csv/204-csv/818.csv
# processing file: WikiTableQuestions/csv/204-csv/819.csv
# processing file: WikiTableQuestions/csv/204-csv/82.csv
# processing file: WikiTableQuestions/csv/204-csv/820.csv
# processing file: WikiTableQuestions/csv/204-csv/821.csv
# processing file: WikiTableQuestions/csv/204-csv/822.csv
# processing file: WikiTableQuestions/csv/204-csv/823.csv
# Error parsing WikiTableQuestions/csv/204-csv/823.csv: Error tokenizing data. C error: Expected 5 fields in line 8, saw 6
#
# processing file: WikiTableQuestions/csv/204-csv/824.csv
# processing file: WikiTableQuestions/csv/204-csv/825.csv
# processing file: WikiTableQuestions/csv/204-csv/826.csv
# processing file: WikiTableQuestions/csv/204-csv/827.csv
# processing file: WikiTableQuestions/csv/204-csv/828.csv
# processing file: WikiTableQuestions/csv/204-csv/829.csv
# processing file: WikiTableQuestions/csv/204-csv/83.csv
# processing file: WikiTableQuestions/csv/204-csv/830.csv
# processing file: WikiTableQuestions/csv/204-csv/831.csv
# Error parsing WikiTableQuestions/csv/204-csv/831.csv: Error tokenizing data. C error: Expected 6 fields in line 13, saw 7
#
# processing file: WikiTableQuestions/csv/204-csv/832.csv
# processing file: WikiTableQuestions/csv/204-csv/833.csv
# processing file: WikiTableQuestions/csv/204-csv/834.csv
# processing file: WikiTableQuestions/csv/204-csv/835.csv
# processing file: WikiTableQuestions/csv/204-csv/836.csv
# processing file: WikiTableQuestions/csv/204-csv/837.csv
# processing file: WikiTableQuestions/csv/204-csv/838.csv
# processing file: WikiTableQuestions/csv/204-csv/839.csv
# processing file: WikiTableQuestions/csv/204-csv/84.csv
# processing file: WikiTableQuestions/csv/204-csv/840.csv
# Error parsing WikiTableQuestions/csv/204-csv/840.csv: Error tokenizing data. C error: Expected 7 fields in line 3, saw 8
#
# processing file: WikiTableQuestions/csv/204-csv/841.csv
# processing file: WikiTableQuestions/csv/204-csv/842.csv
# processing file: WikiTableQuestions/csv/204-csv/843.csv
# processing file: WikiTableQuestions/csv/204-csv/844.csv
# processing file: WikiTableQuestions/csv/204-csv/845.csv
# processing file: WikiTableQuestions/csv/204-csv/846.csv
# processing file: WikiTableQuestions/csv/204-csv/847.csv
# processing file: WikiTableQuestions/csv/204-csv/848.csv
# processing file: WikiTableQuestions/csv/204-csv/849.csv
# processing file: WikiTableQuestions/csv/204-csv/85.csv
# processing file: WikiTableQuestions/csv/204-csv/850.csv
# processing file: WikiTableQuestions/csv/204-csv/851.csv
# Error parsing WikiTableQuestions/csv/204-csv/851.csv: Error tokenizing data. C error: Expected 7 fields in line 14, saw 12
#
# processing file: WikiTableQuestions/csv/204-csv/852.csv
# processing file: WikiTableQuestions/csv/204-csv/853.csv
# processing file: WikiTableQuestions/csv/204-csv/854.csv
# processing file: WikiTableQuestions/csv/204-csv/855.csv
# processing file: WikiTableQuestions/csv/204-csv/856.csv
# processing file: WikiTableQuestions/csv/204-csv/857.csv
# processing file: WikiTableQuestions/csv/204-csv/858.csv
# processing file: WikiTableQuestions/csv/204-csv/859.csv
# processing file: WikiTableQuestions/csv/204-csv/86.csv
# processing file: WikiTableQuestions/csv/204-csv/860.csv
# processing file: WikiTableQuestions/csv/204-csv/861.csv
# processing file: WikiTableQuestions/csv/204-csv/862.csv
# processing file: WikiTableQuestions/csv/204-csv/863.csv
# processing file: WikiTableQuestions/csv/204-csv/864.csv
# processing file: WikiTableQuestions/csv/204-csv/865.csv
# processing file: WikiTableQuestions/csv/204-csv/866.csv
# processing file: WikiTableQuestions/csv/204-csv/867.csv
# processing file: WikiTableQuestions/csv/204-csv/868.csv
# processing file: WikiTableQuestions/csv/204-csv/869.csv
# processing file: WikiTableQuestions/csv/204-csv/87.csv
# processing file: WikiTableQuestions/csv/204-csv/870.csv
# Error parsing WikiTableQuestions/csv/204-csv/870.csv: Error tokenizing data. C error: EOF inside string starting at row 17
# processing file: WikiTableQuestions/csv/204-csv/871.csv
# processing file: WikiTableQuestions/csv/204-csv/872.csv
# processing file: WikiTableQuestions/csv/204-csv/873.csv
# processing file: WikiTableQuestions/csv/204-csv/874.csv
# processing file: WikiTableQuestions/csv/204-csv/875.csv
# processing file: WikiTableQuestions/csv/204-csv/876.csv
# processing file: WikiTableQuestions/csv/204-csv/877.csv
# processing file: WikiTableQuestions/csv/204-csv/878.csv
# processing file: WikiTableQuestions/csv/204-csv/879.csv
# processing file: WikiTableQuestions/csv/204-csv/88.csv
# processing file: WikiTableQuestions/csv/204-csv/880.csv
# processing file: WikiTableQuestions/csv/204-csv/881.csv
# processing file: WikiTableQuestions/csv/204-csv/882.csv
# processing file: WikiTableQuestions/csv/204-csv/883.csv
# processing file: WikiTableQuestions/csv/204-csv/884.csv
# processing file: WikiTableQuestions/csv/204-csv/885.csv
# processing file: WikiTableQuestions/csv/204-csv/886.csv
# processing file: WikiTableQuestions/csv/204-csv/887.csv
# processing file: WikiTableQuestions/csv/204-csv/888.csv
# processing file: WikiTableQuestions/csv/204-csv/889.csv
# processing file: WikiTableQuestions/csv/204-csv/89.csv
# processing file: WikiTableQuestions/csv/204-csv/890.csv
# processing file: WikiTableQuestions/csv/204-csv/891.csv
# processing file: WikiTableQuestions/csv/204-csv/892.csv
# processing file: WikiTableQuestions/csv/204-csv/893.csv
# processing file: WikiTableQuestions/csv/204-csv/894.csv
# processing file: WikiTableQuestions/csv/204-csv/895.csv
# processing file: WikiTableQuestions/csv/204-csv/896.csv
# processing file: WikiTableQuestions/csv/204-csv/897.csv
# processing file: WikiTableQuestions/csv/204-csv/898.csv
# processing file: WikiTableQuestions/csv/204-csv/899.csv
# processing file: WikiTableQuestions/csv/204-csv/9.csv
# processing file: WikiTableQuestions/csv/204-csv/90.csv
# processing file: WikiTableQuestions/csv/204-csv/900.csv
# processing file: WikiTableQuestions/csv/204-csv/901.csv
# processing file: WikiTableQuestions/csv/204-csv/902.csv
# processing file: WikiTableQuestions/csv/204-csv/903.csv
# processing file: WikiTableQuestions/csv/204-csv/904.csv
# processing file: WikiTableQuestions/csv/204-csv/905.csv
# processing file: WikiTableQuestions/csv/204-csv/906.csv
# processing file: WikiTableQuestions/csv/204-csv/907.csv
# processing file: WikiTableQuestions/csv/204-csv/908.csv
# processing file: WikiTableQuestions/csv/204-csv/909.csv
# processing file: WikiTableQuestions/csv/204-csv/91.csv
# processing file: WikiTableQuestions/csv/204-csv/910.csv
# processing file: WikiTableQuestions/csv/204-csv/911.csv
# processing file: WikiTableQuestions/csv/204-csv/912.csv
# processing file: WikiTableQuestions/csv/204-csv/913.csv
# processing file: WikiTableQuestions/csv/204-csv/914.csv
# processing file: WikiTableQuestions/csv/204-csv/915.csv
# processing file: WikiTableQuestions/csv/204-csv/916.csv
# processing file: WikiTableQuestions/csv/204-csv/917.csv
# processing file: WikiTableQuestions/csv/204-csv/918.csv
# processing file: WikiTableQuestions/csv/204-csv/919.csv
# Error parsing WikiTableQuestions/csv/204-csv/919.csv: Error tokenizing data. C error: Expected 5 fields in line 11, saw 6
#
# processing file: WikiTableQuestions/csv/204-csv/92.csv
# processing file: WikiTableQuestions/csv/204-csv/920.csv
# processing file: WikiTableQuestions/csv/204-csv/921.csv
# processing file: WikiTableQuestions/csv/204-csv/922.csv
# processing file: WikiTableQuestions/csv/204-csv/923.csv
# processing file: WikiTableQuestions/csv/204-csv/924.csv
# processing file: WikiTableQuestions/csv/204-csv/925.csv
# processing file: WikiTableQuestions/csv/204-csv/926.csv
# processing file: WikiTableQuestions/csv/204-csv/927.csv
# processing file: WikiTableQuestions/csv/204-csv/928.csv
# processing file: WikiTableQuestions/csv/204-csv/929.csv
# processing file: WikiTableQuestions/csv/204-csv/93.csv
# processing file: WikiTableQuestions/csv/204-csv/930.csv
# processing file: WikiTableQuestions/csv/204-csv/931.csv
# processing file: WikiTableQuestions/csv/204-csv/932.csv
# processing file: WikiTableQuestions/csv/204-csv/933.csv
# processing file: WikiTableQuestions/csv/204-csv/934.csv
# processing file: WikiTableQuestions/csv/204-csv/935.csv
# processing file: WikiTableQuestions/csv/204-csv/936.csv
# processing file: WikiTableQuestions/csv/204-csv/937.csv
# processing file: WikiTableQuestions/csv/204-csv/938.csv
# processing file: WikiTableQuestions/csv/204-csv/939.csv
# processing file: WikiTableQuestions/csv/204-csv/94.csv
# processing file: WikiTableQuestions/csv/204-csv/940.csv
# processing file: WikiTableQuestions/csv/204-csv/941.csv
# processing file: WikiTableQuestions/csv/204-csv/942.csv
# processing file: WikiTableQuestions/csv/204-csv/943.csv
# processing file: WikiTableQuestions/csv/204-csv/944.csv
# processing file: WikiTableQuestions/csv/204-csv/945.csv
# processing file: WikiTableQuestions/csv/204-csv/946.csv
# processing file: WikiTableQuestions/csv/204-csv/947.csv
# processing file: WikiTableQuestions/csv/204-csv/948.csv
# processing file: WikiTableQuestions/csv/204-csv/949.csv
# processing file: WikiTableQuestions/csv/204-csv/95.csv
# processing file: WikiTableQuestions/csv/204-csv/950.csv
# processing file: WikiTableQuestions/csv/204-csv/951.csv
# processing file: WikiTableQuestions/csv/204-csv/952.csv
# processing file: WikiTableQuestions/csv/204-csv/953.csv
# processing file: WikiTableQuestions/csv/204-csv/954.csv
# processing file: WikiTableQuestions/csv/204-csv/955.csv
# processing file: WikiTableQuestions/csv/204-csv/956.csv
# processing file: WikiTableQuestions/csv/204-csv/957.csv
# processing file: WikiTableQuestions/csv/204-csv/958.csv
# processing file: WikiTableQuestions/csv/204-csv/959.csv
# processing file: WikiTableQuestions/csv/204-csv/96.csv
# processing file: WikiTableQuestions/csv/204-csv/960.csv
# processing file: WikiTableQuestions/csv/204-csv/961.csv
# processing file: WikiTableQuestions/csv/204-csv/962.csv
# processing file: WikiTableQuestions/csv/204-csv/963.csv
# processing file: WikiTableQuestions/csv/204-csv/964.csv
# processing file: WikiTableQuestions/csv/204-csv/965.csv
# processing file: WikiTableQuestions/csv/204-csv/966.csv
# Error parsing WikiTableQuestions/csv/204-csv/966.csv: Error tokenizing data. C error: Expected 5 fields in line 11, saw 6
#
# processing file: WikiTableQuestions/csv/204-csv/967.csv
# processing file: WikiTableQuestions/csv/204-csv/968.csv
# processing file: WikiTableQuestions/csv/204-csv/969.csv
# processing file: WikiTableQuestions/csv/204-csv/97.csv
# processing file: WikiTableQuestions/csv/204-csv/970.csv
# processing file: WikiTableQuestions/csv/204-csv/971.csv
# processing file: WikiTableQuestions/csv/204-csv/972.csv
# processing file: WikiTableQuestions/csv/204-csv/973.csv
# processing file: WikiTableQuestions/csv/204-csv/974.csv
# processing file: WikiTableQuestions/csv/204-csv/975.csv
# processing file: WikiTableQuestions/csv/204-csv/976.csv
# processing file: WikiTableQuestions/csv/204-csv/977.csv
# processing file: WikiTableQuestions/csv/204-csv/978.csv
# processing file: WikiTableQuestions/csv/204-csv/979.csv
# processing file: WikiTableQuestions/csv/204-csv/98.csv
# processing file: WikiTableQuestions/csv/204-csv/980.csv
# processing file: WikiTableQuestions/csv/204-csv/981.csv
# Error parsing WikiTableQuestions/csv/204-csv/981.csv: Error tokenizing data. C error: Expected 5 fields in line 6, saw 7
#
# processing file: WikiTableQuestions/csv/204-csv/982.csv
# processing file: WikiTableQuestions/csv/204-csv/983.csv
# processing file: WikiTableQuestions/csv/204-csv/984.csv
# processing file: WikiTableQuestions/csv/204-csv/985.csv
# processing file: WikiTableQuestions/csv/204-csv/986.csv
# processing file: WikiTableQuestions/csv/204-csv/987.csv
# processing file: WikiTableQuestions/csv/204-csv/988.csv
# processing file: WikiTableQuestions/csv/204-csv/989.csv
# processing file: WikiTableQuestions/csv/204-csv/99.csv
# processing file: WikiTableQuestions/csv/204-csv/990.csv
# processing file: WikiTableQuestions/csv/204-csv/991.csv
# processing file: WikiTableQuestions/csv/204-csv/992.csv
# processing file: WikiTableQuestions/csv/204-csv/993.csv
# processing file: WikiTableQuestions/csv/204-csv/994.csv
# processing file: WikiTableQuestions/csv/204-csv/995.csv
# processing file: WikiTableQuestions/csv/204-csv/996.csv
# processing file: WikiTableQuestions/csv/204-csv/997.csv
# processing file: WikiTableQuestions/csv/204-csv/998.csv
# processing file: WikiTableQuestions/csv/204-csv/999.csv

# %%
tableinfo_dir = "WikiTableQuestions_TableInfo"
# !mkdir {tableinfo_dir}
# Out:
# mkdir: WikiTableQuestions_TableInfo: File exists

# %%
print(df.head(5))
# Out:
#                                           Contestant Original\nTribe  \
# 0                        Branka Čudanov\n28, Kikinda        Ga 'dang
# 1                       Gordana Berger\n38, Belgrade          Manobo
# 2                           Ana Mitrić\n23, Belgrade        Ga 'dang
# 3                      Milena Vitanović\n21, Paraćin        Ga 'dang
# 4  Nikola Kovačević\nReturned to game from Ghost ...        Ga 'dang
#
#   First\nSwitch Second\nSwitch Merged\nTribe                 Finish  \
# 0           NaN            NaN           NaN   2nd Voted Out\nDay 7
# 1           NaN            NaN           NaN   1st Voted Out\nDay 4
# 2           NaN            NaN           NaN  3rd Voted Out\nDay 10
# 3           NaN            NaN           NaN  4th Voted Out\nDay 13
# 4           NaN            NaN           NaN  5th Voted Out\nDay 16
#
#                  Ghost\nIsland  Total\nVotes
# 0        1st Eliminated\nDay 9            10
# 1       2nd Eliminated\nDay 12             9
# 2       3rd Eliminated\nDay 15             7
# 3       4th Eliminated\nDay 18             8
# 4  Ghost Island Winner\nDay 32             6

# %%
from typing import List
from pydantic import BaseModel, Field
from llama_index.core.program import LLMTextCompletionProgram
from llama_index.core.bridge.pydantic import BaseModel, Field
#from llama_index.llms.openai import OpenAI
from llama_index.llms.ollama import Ollama
from llama_index.core import Settings
Settings.llm = Ollama(model="llama2", request_timeout=30.0)

class TableInfo(BaseModel):
    """Information regarding a structured table."""

    table_name: str = Field(
        ..., description="table name (must be underscores and NO spaces)"
    )
    table_summary: str = Field(
        ..., description="short, concise summary/caption of the table"
    )


prompt_str = """\
Give me a summary of the table with the following JSON format.

- The table name must be unique to the table and describe it while being concise. 
- Do NOT output a generic table name (e.g. table, my_table).

Do NOT make the table name one of the following: {exclude_table_name_list}

Table:
{table_str}

Summary: """

program = LLMTextCompletionProgram.from_defaults(
    output_cls=TableInfo,
    llm=Ollama(model="llama2", request_timeout=30.0),
    prompt_template_str=prompt_str,
)

# %%
print(tableinfo_dir)
import os
os.getcwd()
results_gen = Path(tableinfo_dir).glob(f"{0}_*")
results_list = list(results_gen)
print(results_list)
# Out:
# WikiTableQuestions_TableInfo
# [PosixPath('WikiTableQuestions_TableInfo/0_Polls.json')]

# %%
import json


def _get_tableinfo_with_index(idx: int) -> str:
    results_gen = Path(tableinfo_dir).glob(f"{idx}_*")
    results_list = list(results_gen)
    if len(results_list) == 0:
        return None  # type: ignore
    elif len(results_list) == 1:
        path = results_list[0]
        return TableInfo.parse_file(path) # type: ignore
    else:
        raise ValueError(
            f"More than one file matching index: {list(results_gen)}"
        )


table_names = set()
table_infos = []
for idx, df in enumerate(dfs):
    table_info = _get_tableinfo_with_index(idx)
    if table_info:
        table_infos.append(table_info)
    else:
        while True:
            df_str = df.head(10).to_csv()
            table_info = program(
                table_str=df_str,
                exclude_table_name_list=str(list(table_names)),
            )
            table_name = table_info.table_name
            #table_name = TableInfo.table_name
            print(f"Processed table: {table_name}")
            if table_name not in table_names:
                table_names.add(table_name)
                break
            else:
                # try again
                print(f"Table name {table_name} already exists, trying again.")
                pass

        out_file = f"{tableinfo_dir}/{idx}_{table_name}.json"
        json.dump(table_info.dict(), open(out_file, "w"))
    table_infos.append(table_info)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[6], line 27
#      25 while True:
#      26     df_str = df.head(10).to_csv()
# ---> 27     table_info = program(
#      28         table_str=df_str,
#      29         exclude_table_name_list=str(list(table_names)),
#      30     )
#      31     table_name = table_info.table_name
#      32     #table_name = TableInfo.table_name
#
# File ~/GitHub_OCHCO/llama_index_sql/llama_index_sql_venv/lib/python3.10/site-packages/llama_index/core/program/llm_program.py:103, in LLMTextCompletionProgram.__call__(self, llm_kwargs, *args, **kwargs)
#      99     response = self._llm.complete(formatted_prompt, **llm_kwargs)
#     101     raw_output = response.text
# --> 103 output = self._output_parser.parse(raw_output)
#     104 if not isinstance(output, self._output_cls):
#     105     raise ValueError(
#     106         f"Output parser returned {type(output)} but expected {self._output_cls}"
#     107     )
#
# File ~/GitHub_OCHCO/llama_index_sql/llama_index_sql_venv/lib/python3.10/site-packages/llama_index/core/output_parsers/pydantic.py:62, in PydanticOutputParser.parse(self, text)
#      60 """Parse, validate, and correct errors programmatically."""
#      61 json_str = extract_json_str(text)
# ---> 62 return self._output_cls.parse_raw(json_str)
#
# File ~/GitHub_OCHCO/llama_index_sql/llama_index_sql_venv/lib/python3.10/site-packages/pydantic/v1/main.py:549, in BaseModel.parse_raw(cls, b, content_type, encoding, proto, allow_pickle)
#     547 except (ValueError, TypeError, UnicodeDecodeError) as e:
#     548     raise ValidationError([ErrorWrapper(e, loc=ROOT_KEY)], cls)
# --> 549 return cls.parse_obj(obj)
#
# File ~/GitHub_OCHCO/llama_index_sql/llama_index_sql_venv/lib/python3.10/site-packages/pydantic/v1/main.py:526, in BaseModel.parse_obj(cls, obj)
#     524         exc = TypeError(f'{cls.__name__} expected dict not {obj.__class__.__name__}')
#     525         raise ValidationError([ErrorWrapper(exc, loc=ROOT_KEY)], cls) from e
# --> 526 return cls(**obj)
#
# File ~/GitHub_OCHCO/llama_index_sql/llama_index_sql_venv/lib/python3.10/site-packages/pydantic/v1/main.py:341, in BaseModel.__init__(__pydantic_self__, **data)
#     339 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340 if validation_error:
# --> 341     raise validation_error
#     342 try:
#     343     object_setattr(__pydantic_self__, '__dict__', values)
#
# ValidationError: 2 validation errors for TableInfo
# table_name
#   field required (type=value_error.missing)
# table_summary
#   field required (type=value_error.missing)

# %%
# put data into sqlite db
from sqlalchemy import (
    create_engine,
    MetaData,
    Table,
    Column,
    String,
    Integer,
)
import re


# Function to create a sanitized column name
def sanitize_column_name(col_name):
    # Remove special characters and replace spaces with underscores
    return re.sub(r"\W+", "_", col_name)


# Function to create a table from a DataFrame using SQLAlchemy
def create_table_from_dataframe(
    df: pd.DataFrame, table_name: str, engine, metadata_obj
):
    # Sanitize column names
    sanitized_columns = {col: sanitize_column_name(col) for col in df.columns}
    df = df.rename(columns=sanitized_columns)

    # Dynamically create columns based on DataFrame columns and data types
    columns = [
        Column(col, String if dtype == "object" else Integer)
        for col, dtype in zip(df.columns, df.dtypes)
    ]

    # Create a table with the defined columns
    table = Table(table_name, metadata_obj, *columns)

    # Create the table in the database
    metadata_obj.create_all(engine)

    # Insert data from DataFrame into the table
    with engine.connect() as conn:
        for _, row in df.iterrows():
            insert_stmt = table.insert().values(**row.to_dict())
            conn.execute(insert_stmt)
        conn.commit()


engine = create_engine("sqlite:///:memory:")
metadata_obj = MetaData()
for idx, df in enumerate(dfs):
    tableinfo = _get_tableinfo_with_index(idx)
    print(f"Creating table: {tableinfo.table_name}")
    create_table_from_dataframe(df, tableinfo.table_name, engine, metadata_obj)

# %% [markdown]
# Advanced Capability 1: Text-to-SQL with Query-Time Table Retrieval.
# We now show you how to setup an e2e text-to-SQL with table retrieval.
#
# Define Modules
# Here we define the core modules.
#
# Object index + retriever to store table schemas
#
# SQLDatabase object to connect to the above tables + SQLRetriever.
#
# Text-to-SQL Prompt
#
# Response synthesis Prompt
#
# LLM
#
# Object index, retriever, SQLDatabase

# %%
from llama_index.core.objects import (
    SQLTableNodeMapping,
    ObjectIndex,
    SQLTableSchema,
)
from llama_index.core import SQLDatabase, VectorStoreIndex

sql_database = SQLDatabase(engine)

table_node_mapping = SQLTableNodeMapping(sql_database)
table_schema_objs = [
    SQLTableSchema(table_name=t.table_name, context_str=t.table_summary)
    for t in table_infos
]  # add a SQLTableSchema for each table

obj_index = ObjectIndex.from_objects(
    table_schema_objs,
    table_node_mapping,
    VectorStoreIndex,
)
obj_retriever = obj_index.as_retriever(similarity_top_k=3)

# %% [markdown]
# SQLRetriever + Table Parser

# %%
from llama_index.core.retrievers import SQLRetriever
from typing import List
from llama_index.core.query_pipeline import FnComponent

sql_retriever = SQLRetriever(sql_database)


def get_table_context_str(table_schema_objs: List[SQLTableSchema]):
    """Get table context string."""
    context_strs = []
    for table_schema_obj in table_schema_objs:
        table_info = sql_database.get_single_table_info(
            table_schema_obj.table_name
        )
        if table_schema_obj.context_str:
            table_opt_context = " The table description is: "
            table_opt_context += table_schema_obj.context_str
            table_info += table_opt_context

        context_strs.append(table_info)
    return "\n\n".join(context_strs)


table_parser_component = FnComponent(fn=get_table_context_str)

# %% [markdown]
# Text-to-SQL Prompt + Output Parser

# %%
from llama_index.core.prompts.default_prompts import DEFAULT_TEXT_TO_SQL_PROMPT
from llama_index.core import PromptTemplate
from llama_index.core.query_pipeline import FnComponent
from llama_index.core.llms import ChatResponse


def parse_response_to_sql(response: ChatResponse) -> str:
    """Parse response to SQL."""
    response = response.message.content
    sql_query_start = response.find("SQLQuery:")
    if sql_query_start != -1:
        response = response[sql_query_start:]
        # TODO: move to removeprefix after Python 3.9+
        if response.startswith("SQLQuery:"):
            response = response[len("SQLQuery:") :]
    sql_result_start = response.find("SQLResult:")
    if sql_result_start != -1:
        response = response[:sql_result_start]
    return response.strip().strip("```").strip()


sql_parser_component = FnComponent(fn=parse_response_to_sql)

text2sql_prompt = DEFAULT_TEXT_TO_SQL_PROMPT.partial_format(
    dialect=engine.dialect.name
)
print(text2sql_prompt.template)

# %% [markdown]
# Response Synthesis Prompt

# %%
response_synthesis_prompt_str = (
    "Given an input question, synthesize a response from the query results.\n"
    "Query: {query_str}\n"
    "SQL: {sql_query}\n"
    "SQL Response: {context_str}\n"
    "Response: "
)
response_synthesis_prompt = PromptTemplate(
    response_synthesis_prompt_str,
)

# %%
llm = OpenAI(model="gpt-3.5-turbo")

# %% [markdown]
# Define Query Pipeline
# Now that the components are in place, let’s define the query pipeline!

# %%
from llama_index.core.query_pipeline import (
    QueryPipeline as QP,
    Link,
    InputComponent,
    CustomQueryComponent,
)

qp = QP(
    modules={
        "input": InputComponent(),
        "table_retriever": obj_retriever,
        "table_output_parser": table_parser_component,
        "text2sql_prompt": text2sql_prompt,
        "text2sql_llm": llm,
        "sql_output_parser": sql_parser_component,
        "sql_retriever": sql_retriever,
        "response_synthesis_prompt": response_synthesis_prompt,
        "response_synthesis_llm": llm,
    },
    verbose=True,
)

# %%
qp.add_chain(["input", "table_retriever", "table_output_parser"])
qp.add_link("input", "text2sql_prompt", dest_key="query_str")
qp.add_link("table_output_parser", "text2sql_prompt", dest_key="schema")
qp.add_chain(
    ["text2sql_prompt", "text2sql_llm", "sql_output_parser", "sql_retriever"]
)
qp.add_link(
    "sql_output_parser", "response_synthesis_prompt", dest_key="sql_query"
)
qp.add_link(
    "sql_retriever", "response_synthesis_prompt", dest_key="context_str"
)
qp.add_link("input", "response_synthesis_prompt", dest_key="query_str")
qp.add_link("response_synthesis_prompt", "response_synthesis_llm")

# %% [markdown]
# Visualize Query Pipeline
# A really nice property of the query pipeline syntax is you can easily visualize it in a graph via networkx.

# %%
from pyvis.network import Network

net = Network(notebook=True, cdn_resources="in_line", directed=True)
net.from_nx(qp.dag)
net.show("text2sql_dag.html")

# %% [markdown]
# Run Some Queries!
# Now we’re ready to run some queries across this entire pipeline

# %%
response = qp.run(
    query="What was the year that The Notorious B.I.G was signed to Bad Boy?"
)
print(str(response))

# %%
response = qp.run(query="Who won best director in the 1972 academy awards")
print(str(response))

# %%
response = qp.run(query="What was the term of Pasquale Preziosa?")
print(str(response))
